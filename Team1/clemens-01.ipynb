# %% [markdown]
# ### Inleiding
#
# Ik probeer de bacterie tabel(len) te visualiseren.

# %%
import numpy as np
import pandas as pd

# %%
# Pivot_ZAWZI_Ranked-Table 1

d1 = pd.read_csv('./data/Pivot_ZAWZI_Ranked-Table 1.csv', sep=';', decimal ='.', skiprows=8, header=1)

# %%
d1.sample(5)
# Out:
#          Domain          Phylum               Class  \
# 414    Bacteria  Proteobacteria  Betaproteobacteria
# 1661   Bacteria  Actinobacteria      Actinobacteria
# 1176   Bacteria   Bacteroidetes      Flavobacteriia
# 1725   Bacteria      Firmicutes          Clostridia
# 1247  Eukaryota    Opisthokonta             Holozoa
#
#                          Genera  Frequentie  Aantal > -1  Aantal > -2    Max  \
# 414   Candidatus Accumulibacter          21            0            0  -4,08
# 1661           Jatrophihabitans           1            0            0  -4,96
# 1176                 Flavivirga           5            0            0  -4,07
# 1725               Natronincola           1            0            0  -5,54
# 1247                      Acari           4            0            0  -3,67
#
#         Min Difference  ...        W      X    Y      Z   ZA   ZB   ZC     ZD  \
# 414   -5,11       1,03  ...      NaN  -4,69  NaN  -4,66  NaN  NaN  NaN  -4,08
# 1661  -4,96       0,00  ...      NaN    NaN  NaN    NaN  NaN  NaN  NaN    NaN
# 1176  -5,31       1,24  ...      NaN    NaN  NaN    NaN  NaN  NaN  NaN    NaN
# 1725  -5,54       0,00  ...      NaN    NaN  NaN    NaN  NaN  NaN  NaN    NaN
# 1247  -5,40       1,74  ...    -4,36    NaN  NaN    NaN  NaN  NaN  NaN    NaN
#
#        ZE     ZF
# 414   NaN  -4,75
# 1661  NaN    NaN
# 1176  NaN    NaN
# 1725  NaN    NaN
# 1247  NaN    NaN
#
# [5 rows x 42 columns]
