# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
# Mac adds ''-Table 1' to the csv files :-(
file = '../../ds-wln/datasets/Kennisnetwerk_procesdata_kwaliteitsdata_WLN/SVI en DS AT-Table 1.csv'

d1 = pd.read_csv(file , sep=';', decimal =',', header=0)

# %%
d1
# Out:
#         datum  D STOF AT       SVI 5      SVI 10      SVI 15      SVI 20  \
# 0     9/26/14     4400.0   91.891892   75.675676   64.864865   54.054054
# 1     9/30/14     4600.0   54.761905   52.380952   50.000000   47.619048
# 2     10/3/14     4600.0   85.653105   74.946467   64.239829   59.957173
# 3     10/7/14     4100.0  112.903226   80.645161   69.892473   61.827957
# 4    10/10/14     4200.0  114.503817   76.335878   66.157761   61.068702
# 5    10/14/14     4600.0   96.938776   79.081633   66.326531   61.224490
# 6    10/17/14     4800.0  121.428571   97.619048   85.714286   73.809524
# 7    10/21/14     5600.0  136.956522  100.000000   84.782609   80.434783
# 8    10/24/14     5600.0  126.637555  102.620087   89.519651   85.152838
# 9    10/28/14     5200.0  135.972805  115.976805   95.980804   87.982404
# 10   10/31/14     4600.0  167.042889  130.925508  108.352144  101.580135
# 11    11/3/14     4600.0  215.384615  191.208791  153.846154  138.461538
# ...

# %%
pd.to_datetime('6/7/16')

# %%
# Parse datetimes, reset time to midnight.
#d1 = d1.assign(date=pd.to_datetime(d1['datum'], format='%d-%m-%Y', infer_datetime_format=True).dt.normalize())
d1 = d1.assign(date=pd.to_datetime(d1['datum']))
#d1 = d1.drop('Datum', axis=1)
#d1 = d1.set_index('date')

# %%
pwd

# %%
ls ../../ds-wln/datasets/Kennisnetwerk_procesdata_kwaliteitsdata_WLN/slibactiviteit-Table\ 1.csv

# %%
d_err = d1.iloc[:200, 0]
pd.to_datetime(d_err)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/share/virtualenvs/Team1-9K3ihJ0V/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-16-997fba0cdc5e> in <module>
#       1 d_err = d1.iloc[:200, 0]
# ----> 2 pd.to_datetime(d_err)
#
# ...

# %%
d_err = d1.iloc[200:, 0]
pd.to_datetime(d_err)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/share/virtualenvs/Team1-9K3ihJ0V/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-17-d5265ab9b29e> in <module>
#       1 d_err = d1.iloc[200:, 0]
# ----> 2 pd.to_datetime(d_err)
#
# ...

# %%
pd.to_datetime(d_err)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/share/virtualenvs/Team1-9K3ihJ0V/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-15-80205674efef> in <module>
#       1 d_err = d1.iloc[200:, 0]
#       2
# ----> 3 pd.to_datetime(d_err)
#
# ...
