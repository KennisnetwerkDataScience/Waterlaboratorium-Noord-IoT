# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
file = '../../ds-wln/datasets/Kennisnetwerk_procesdata_kwaliteitsdata_WLN/SVI en DS AT.csv'

d1 = pd.read_csv(file , sep=';', decimal =',', header=0)

# %%
d1
# Out:
#     datum,"D STOF AT","SVI 5","SVI 10","SVI 15","SVI 20","SVI 25","SVI 30"
# 0    09/26/14,4400,91.8918918918919,75.675675675675...
# 1    09/30/14,4600,54.7619047619048,52.380952380952...
# 2    10/03/14,4600,85.6531049250535,74.946466809421...
# 3    10/07/14,4100,112.903225806452,80.645161290322...
# 4    10/10/14,4200,114.503816793893,76.335877862595...
# 5    10/14/14,4600,96.9387755102041,79.081632653061...
# 6    10/17/14,4800,121.428571428571,97.619047619047...
# 7    10/21/14,5600,136.95652173913,100,84.782608695...
# 8    10/24/14,5600,126.637554585153,102.62008733624...
# 9    10/28/14,5200,135.972805438912,115.97680463907...
# 10   10/31/14,4600,167.042889390519,130.92550790067...
# 11   11/03/14,4600,215.384615384615,191.20879120879...
# 12   11/07/14,4600,219.026548672566,214.60176991150...
# 13   11/10/14,5000,200.811359026369,190.66937119675...
# 14   11/12/14,5300,186.09022556391,169.172932330827...
# 15               11/18/14,4300,360,240,184,160,144,124
# ...

# %%
pd.to_datetime('6/7/16')
# Out:
# Timestamp('2016-06-07 00:00:00')

# %%
# Parse datetimes, reset time to midnight.
#d1 = d1.assign(date=pd.to_datetime(d1['datum'], format='%d-%m-%Y', infer_datetime_format=True).dt.normalize())
d1 = d1.assign(date=pd.to_datetime(d1['datum']))
d1 = d1.drop('datum', axis=1)
d1 = d1.set_index('date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/Team1-9K3ihJ0V/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'datum'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-f65a505ab67e> in <module>
# ...

# %%
pwd

# %%
# ls ../../ds-wln/datasets/Kennisnetwerk_procesdata_kwaliteitsdata_WLN/slibactiviteit-Table\ 1.csv

# %%
# d_err = d1.iloc[:200, 0]
# print(d_err)
# pd.to_datetime(d_err)

# %%
# d_err = d1.iloc[200:, 0]
# pd.to_datetime(d_err)

# %%
# pd.to_datetime(d_err)
